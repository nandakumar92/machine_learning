# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

df=pd.read_csv('/kaggle/input/netflix-shows/netflix_titles.csv')

display(df)
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/netflix-shows/netflix_titles.csv
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
s=pd.Series(df['country'])
s
# Out:
# 0       United States
# 1        South Africa
# 2                 NaN
# 3                 NaN
# 4               India
#             ...
# 8802    United States
# 8803              NaN
# 8804    United States
# 8805    United States
# 8806            India
# Name: country, Length: 8807, dtype: object

# %%
# sorting

df.sort_values(by='date_added', ascending=False)
# Out:
#      show_id     type                                     title  \
# 88       s89    Movie  Blood Brothers: Malcolm X & Muhammad Ali
# 89       s90  TV Show                               Mighty Raju
# 90       s91    Movie                            Paradise Hills
# 91       s92    Movie                The Women and the Murderer
# 2034   s2035    Movie                      So Much Love to Give
# ...      ...      ...                                       ...
# 7196   s7197  TV Show                                  Kikoriki
# 7254   s7255  TV Show                       La Familia P. Luche
# 7406   s7407  TV Show                                     Maron
# 7847   s7848  TV Show                              Red vs. Blue
# 8182   s8183  TV Show              The Adventures of Figaro Pho
#
#                                 director  \
# 88                         Marcus Clarke
# 89                                   NaN
# 90                      Alice Waddington
# ...

# %%
df.sort_values(by=['date_added','country'],ascending=[False,True])
# Out:
#      show_id     type                                     title  \
# 91       s92    Movie                The Women and the Murderer
# 90       s91    Movie                            Paradise Hills
# 88       s89    Movie  Blood Brothers: Malcolm X & Muhammad Ali
# 89       s90  TV Show                               Mighty Raju
# 2034   s2035    Movie                      So Much Love to Give
# ...      ...      ...                                       ...
# 6806   s6807  TV Show                                   Friends
# 7254   s7255  TV Show                       La Familia P. Luche
# 7406   s7407  TV Show                                     Maron
# 7847   s7848  TV Show                              Red vs. Blue
# 7196   s7197  TV Show                                  Kikoriki
#
#                                 director  \
# 91    Mona Achache, Patricia Tourancheau
# 90                      Alice Waddington
# 88                         Marcus Clarke
# ...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df['country'].unique
# Out:
# <bound method Series.unique of 0       United States
# 1        South Africa
# 2                 NaN
# 3                 NaN
# 4               India
#             ...
# 8802    United States
# 8803              NaN
# 8804    United States
# 8805    United States
# 8806            India
# Name: country, Length: 8807, dtype: object>

# %%
## dot method selection

df.country.unique
# Out:
# <bound method Series.unique of 0       United States
# 1        South Africa
# 2                 NaN
# 3                 NaN
# 4               India
#             ...
# 8802    United States
# 8803              NaN
# 8804    United States
# 8805    United States
# 8806            India
# Name: country, Length: 8807, dtype: object>

# %%
df['country'][0:10]
# Out:
# 0                                        United States
# 1                                         South Africa
# 2                                                  NaN
# 3                                                  NaN
# 4                                                India
# 5                                                  NaN
# 6                                                  NaN
# 7    United States, Ghana, Burkina Faso, United Kin...
# 8                                       United Kingdom
# 9                                        United States
# Name: country, dtype: object

# %%
# select multiple columns with a list
df[['country','date_added']].head()
# Out:
#          country          date_added
# 0  United States  September 25, 2021
# 1   South Africa  September 24, 2021
# 2            NaN  September 24, 2021
# 3            NaN  September 24, 2021
# 4          India  September 24, 2021

# %%
## index based selection

df[0:10]
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
## show first row index

df.iloc[0]
# Out:
# show_id                                                        s1
# type                                                        Movie
# title                                        Dick Johnson Is Dead
# director                                          Kirsten Johnson
# cast                                                          NaN
# country                                             United States
# date_added                                     September 25, 2021
# release_year                                                 2020
# rating                                                      PG-13
# duration                                                   90 min
# listed_in                                           Documentaries
# description     As her father nears the end of his life, filmm...
# Name: 0, dtype: object

# %%
## get second column
df.iloc[:,1].head()
# Out:
# 0      Movie
# 1    TV Show
# 2    TV Show
# 3    TV Show
# 4    TV Show
# Name: type, dtype: object

# %%
## to select only first three 3 rows and second column

df.iloc[:3,1]
# Out:
# 0      Movie
# 1    TV Show
# 2    TV Show
# Name: type, dtype: object

# %%
df.iloc[:10]
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
## fropm last -5 rows

df.iloc[-5:]
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
# first 10 rows, columns 2 to 4
df.iloc[:10,2:5]
# Out:
#                               title                       director  \
# 0              Dick Johnson Is Dead                Kirsten Johnson
# 1                     Blood & Water                            NaN
# 2                         Ganglands                Julien Leclercq
# 3             Jailbirds New Orleans                            NaN
# 4                      Kota Factory                            NaN
# 5                     Midnight Mass                  Mike Flanagan
# 6  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7                           Sankofa                   Haile Gerima
# 8     The Great British Baking Show                Andy Devonshire
# 9                      The Starling                 Theodore Melfi
#
#                                                 cast
# 0                                                NaN
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
# label based selection

df['country']
# Out:
# 0       United States
# 1        South Africa
# 2                 NaN
# 3                 NaN
# 4               India
#             ...
# 8802    United States
# 8803              NaN
# 8804    United States
# 8805    United States
# 8806            India
# Name: country, Length: 8807, dtype: object

# %%
## give me first row and director column
df.loc[0,'director']
# Out:
# 'Kirsten Johnson'

# %%
# first 10 rows, two columns selection
df.loc[:10,['director','cast']]
# Out:
#                          director  \
# 0                 Kirsten Johnson
# 1                             NaN
# 2                 Julien Leclercq
# 3                             NaN
# 4                             NaN
# 5                   Mike Flanagan
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 8                 Andy Devonshire
# 9                  Theodore Melfi
# 10                            NaN
#
#                                                  cast
# 0                                                 NaN
# 1   Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2   Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                 NaN
# 4   Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5   Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# ...

# %%
## conditional selection

df.country=='France'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806    False
# Name: country, Length: 8807, dtype: bool

# %%
df[df.country=='France']
# Out:
#      show_id     type                       title  \
# 91       s92    Movie  The Women and the Murderer
# 188     s189    Movie            2 Alone in Paris
# 273     s274  TV Show               Gone for Good
# 299     s300    Movie                   The Swarm
# 553     s554  TV Show                      Mortel
# ...      ...      ...                         ...
# 8218   s8219    Movie         The Boss's Daughter
# 8370   s8371    Movie        The Jack King Affair
# 8423   s8424  TV Show         The Minimighty Kids
# 8482   s8483  TV Show                The Returned
# 8563   s8564    Movie                The Workshop
#
#                                 director  \
# 91    Mona Achache, Patricia Tourancheau
# 188              Ramzy Bedia, Éric Judor
# 273                   Juan Carlos Medina
# 299                       Just Philippot
# 553                                  NaN
# ...                                  ...
# 8218                     Olivier Loustau
# ...

# %%
df[df['country']=='France']
# Out:
#      show_id     type                       title  \
# 91       s92    Movie  The Women and the Murderer
# 188     s189    Movie            2 Alone in Paris
# 273     s274  TV Show               Gone for Good
# 299     s300    Movie                   The Swarm
# 553     s554  TV Show                      Mortel
# ...      ...      ...                         ...
# 8218   s8219    Movie         The Boss's Daughter
# 8370   s8371    Movie        The Jack King Affair
# 8423   s8424  TV Show         The Minimighty Kids
# 8482   s8483  TV Show                The Returned
# 8563   s8564    Movie                The Workshop
#
#                                 director  \
# 91    Mona Achache, Patricia Tourancheau
# 188              Ramzy Bedia, Éric Judor
# 273                   Juan Carlos Medina
# 299                       Just Philippot
# 553                                  NaN
# ...                                  ...
# 8218                     Olivier Loustau
# ...

# %%
df.loc[(df.country=='France') & (df.type=='Movie')]
# Out:
#      show_id   type                       title  \
# 91       s92  Movie  The Women and the Murderer
# 188     s189  Movie            2 Alone in Paris
# 299     s300  Movie                   The Swarm
# 634     s635  Movie                  Wonder Boy
# 1110   s1111  Movie               Madame Claude
# ...      ...    ...                         ...
# 8150   s8151  Movie               Tarif de nuit
# 8168   s8169  Movie                       Terra
# 8218   s8219  Movie         The Boss's Daughter
# 8370   s8371  Movie        The Jack King Affair
# 8563   s8564  Movie                The Workshop
#
#                                   director  \
# 91      Mona Achache, Patricia Tourancheau
# 188                Ramzy Bedia, Éric Judor
# 299                         Just Philippot
# 634                       Anissa Bonnefont
# 1110                       Sylvie Verheyde
# ...                                    ...
# 8150                           Julien Seri
# ...

# %%
df[(df.country=='France') & (df.type=='TV Show')]
# Out:
#      show_id     type                                  title  \
# 273     s274  TV Show                          Gone for Good
# 553     s554  TV Show                                 Mortel
# 661     s662  TV Show                         Call My Agent!
# 1223   s1224  TV Show                                 Dealer
# 1365   s1366  TV Show                           Zig & Sharko
# 1555   s1556  TV Show                 Grizzy et les Lemmings
# 1586   s1587  TV Show              Room 2806: The Accusation
# 1839   s1840  TV Show                          La Révolution
# 2008   s2009  TV Show                        Family Business
# 2069   s2070  TV Show                                      H
# 2225   s2226  TV Show                          Gigantosaurus
# 2318   s2319  TV Show                                 Trotro
# 2522   s2523  TV Show                      Inhuman Resources
# 2675   s2676  TV Show                        Fary : Hexagone
# ...

# %%
## or selection

df[(df.country=='France') | (df.release_year==2021)]
# Out:
#      show_id     type                   title                       director  \
# 1         s2  TV Show           Blood & Water                            NaN
# 2         s3  TV Show               Ganglands                Julien Leclercq
# 3         s4  TV Show   Jailbirds New Orleans                            NaN
# 4         s5  TV Show            Kota Factory                            NaN
# 5         s6  TV Show           Midnight Mass                  Mike Flanagan
# ...      ...      ...                     ...                            ...
# 8370   s8371    Movie    The Jack King Affair  Benjamin Cohen, Nicolas Cotto
# 8423   s8424  TV Show     The Minimighty Kids                            NaN
# 8437   s8438  TV Show  The Netflix Afterparty                            NaN
# 8482   s8483  TV Show            The Returned                            NaN
# 8563   s8564    Movie            The Workshop                 Laurent Cantet
#
# ...

# %%
# in selection

df[df.country.isin(['France','Italy'])]
# Out:
#      show_id     type                       title  \
# 91       s92    Movie  The Women and the Murderer
# 188     s189    Movie            2 Alone in Paris
# 269     s270  TV Show                   Winx Club
# 273     s274  TV Show               Gone for Good
# 299     s300    Movie                   The Swarm
# ...      ...      ...                         ...
# 8423   s8424  TV Show         The Minimighty Kids
# 8432   s8433    Movie        The Music of Silence
# 8482   s8483  TV Show                The Returned
# 8506   s8507    Movie           The Sign of Venus
# 8563   s8564    Movie                The Workshop
#
#                                 director  \
# 91    Mona Achache, Patricia Tourancheau
# 188              Ramzy Bedia, Éric Judor
# 269                                  NaN
# 273                   Juan Carlos Medina
# 299                       Just Philippot
# ...                                  ...
# 8423                                 NaN
# ...

# %%
## select not null values

df[df.country.notnull()]
# Out:
#      show_id     type                          title         director  \
# 0         s1    Movie           Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show                  Blood & Water              NaN
# 4         s5  TV Show                   Kota Factory              NaN
# 7         s8    Movie                        Sankofa     Haile Gerima
# 8         s9  TV Show  The Great British Baking Show  Andy Devonshire
# ...      ...      ...                            ...              ...
# 8801   s8802    Movie                        Zinzana  Majid Al Ansari
# 8802   s8803    Movie                         Zodiac    David Fincher
# 8804   s8805    Movie                     Zombieland  Ruben Fleischer
# 8805   s8806    Movie                           Zoom     Peter Hewitt
# 8806   s8807    Movie                         Zubaan      Mozez Singh
#
#                                                    cast  \
# 0                                                   NaN
# ...

# %%
df[df.country.isnull()]
# Out:
#      show_id     type                                title  \
# 2         s3  TV Show                            Ganglands
# 3         s4  TV Show                Jailbirds New Orleans
# 5         s6  TV Show                        Midnight Mass
# 6         s7    Movie     My Little Pony: A New Generation
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia
# ...      ...      ...                                  ...
# 8718   s8719    Movie               Westside vs. the World
# 8759   s8760    Movie               World's Weirdest Homes
# 8783   s8784  TV Show                                 Yoko
# 8785   s8786  TV Show                                  YOM
# 8803   s8804  TV Show                          Zombie Dumb
#
#                            director  \
# 2                   Julien Leclercq
# 3                               NaN
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 10                              NaN
# ...

# %%
df[['country','date_added']].head()
# Out:
#          country          date_added
# 0  United States  September 25, 2021
# 1   South Africa  September 24, 2021
# 2            NaN  September 24, 2021
# 3            NaN  September 24, 2021
# 4          India  September 24, 2021

# %%
# grouping

df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.country.value_counts()
# Out:
# country
# United States                             2818
# India                                      972
# United Kingdom                             419
# Japan                                      245
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: count, Length: 748, dtype: int64

# %%
df.groupby('type').count()
# Out:
#          show_id  title  director  cast  country  date_added  release_year  \
# type
# Movie       6131   6131      5943  5656     5691        6131          6131
# TV Show     2676   2676       230  2326     2285        2666          2676
#
#          rating  duration  listed_in  description
# type
# Movie      6129      6128       6131         6131
# TV Show    2674      2676       2676         2676

# %%
df.groupby(['type','country']).country.count().
# Out:
# type     country
# Movie    , France, Algeria                                       1
#          Argentina                                              38
#          Argentina, Brazil, France, Poland, Germany, Denmark     1
#          Argentina, Chile                                        2
#          Argentina, Chile, Peru                                  1
#                                                                 ..
# TV Show  United States, South Korea, China                       2
#          United States, Sweden                                   1
#          United States, United Kingdom                           9
#          United States, United Kingdom, Australia                1
#          Uruguay, Germany                                        1
# Name: country, Length: 847, dtype: int64

# %% [raw]
# df.groupby(['type','country']).count()

# %%
df.groupby(['country']).release_year.agg(['max','min'])
# Out:
#                                                      max   min
# country
# , France, Algeria                                   2014  2014
# , South Korea                                       2021  2021
# Argentina                                           2021  1985
# Argentina, Brazil, France, Poland, Germany, Den...  2017  2017
# Argentina, Chile                                    2017  2006
# ...                                                  ...   ...
# Venezuela                                           2017  2017
# Venezuela, Colombia                                 2007  2007
# Vietnam                                             2021  2014
# West Germany                                        1977  1977
# Zimbabwe                                            2017  2017
#
# [748 rows x 2 columns]

# %%
df.groupby(['type']).release_year.agg(['count','min','max']).sort_values(by='count',ascending=True)
# Out:
#          count   min   max
# type
# TV Show   2676  1925  2021
# Movie     6131  1942  2021

# %%
## reset index

df.groupby(['type','country']).release_year.count().reset_index().head()
# Out:
#     type                                            country  release_year
# 0  Movie                                  , France, Algeria             1
# 1  Movie                                          Argentina            38
# 2  Movie  Argentina, Brazil, France, Poland, Germany, De...             1
# 3  Movie                                   Argentina, Chile             2
# 4  Movie                             Argentina, Chile, Peru             1

# %%
# group by with alias 

df.groupby('type').agg(max_year=('release_year','max'), min_year=('release_year','min')).sort_values(by='min_year',ascending=True)
# Out:
#          max_year  min_year
# type
# TV Show      2021      1925
# Movie        2021      1942

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# casting

df['release_year'].astype('float64')
# Out:
# 0       2020.0
# 1       2021.0
# 2       2021.0
# 3       2021.0
# 4       2021.0
#          ...
# 8802    2007.0
# 8803    2018.0
# 8804    2009.0
# 8805    2006.0
# 8806    2015.0
# Name: release_year, Length: 8807, dtype: float64

# %%
df[df.country.isnull()]
# Out:
#      show_id     type                                title  \
# 2         s3  TV Show                            Ganglands
# 3         s4  TV Show                Jailbirds New Orleans
# 5         s6  TV Show                        Midnight Mass
# 6         s7    Movie     My Little Pony: A New Generation
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia
# ...      ...      ...                                  ...
# 8718   s8719    Movie               Westside vs. the World
# 8759   s8760    Movie               World's Weirdest Homes
# 8783   s8784  TV Show                                 Yoko
# 8785   s8786  TV Show                                  YOM
# 8803   s8804  TV Show                          Zombie Dumb
#
#                            director  \
# 2                   Julien Leclercq
# 3                               NaN
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 10                              NaN
# ...

# %%
df.country.fillna('unknown',inplace=True)
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        unknown
# 3                                                NaN        unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df_1=df[df.country=='Italy']
df_2=df[df.country=='Spain']

df_r=pd.concat([df_1,df_2])
df_r.head()
# Out:
#     show_id     type                   title                         director  \
# 269    s270  TV Show               Winx Club                              NaN
# 324    s325  TV Show                 44 Cats                              NaN
# 463    s464    Movie  A Classic Horror Story  Roberto De Feo, Paolo Strippoli
# 711    s712    Movie                Security                    Peter Chelsom
# 772    s773  TV Show              Summertime                              NaN
#
#                                                   cast country  \
# 269  Liza Jacqueline, Helena Evangeliou, Lisa Ortiz...   Italy
# 324  Sarah Natochenny, Suzy Myers, Simona Berman, E...   Italy
# 463  Matilda Lutz, Francesco Russo, Peppino Mazzott...   Italy
# 711  Marco D'Amore, Maya Sansa, Silvio Muccino, Val...   Italy
# 772  Coco Rebecca Edogamhe, Ludovico Tersigni, Aman...   Italy
#
#           date_added  release_year rating   duration  \
# 269  August 15, 2021          2015  TV-Y7  2 Seasons
# ...

# %%
df_r=pd.concat([df_1,df_2],axis=1)
df_r.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        unknown
# 3                                                NaN        unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df_1=df[['country','release_year','type','show_id']]
df_2=df[['country','release_year','type','show_id','cast','rating','director']]
df_r=pd.merge(df_1,df_2,on=['show_id','type'],how='inner')
df_r
# Out:
#           country_x  release_year_x     type show_id      country_y  \
# 0     United States            2020    Movie      s1  United States
# 1      South Africa            2021  TV Show      s2   South Africa
# 2           unknown            2021  TV Show      s3        unknown
# 3           unknown            2021  TV Show      s4        unknown
# 4             India            2021  TV Show      s5          India
# ...             ...             ...      ...     ...            ...
# 8802  United States            2007    Movie   s8803  United States
# 8803        unknown            2018  TV Show   s8804        unknown
# 8804  United States            2009    Movie   s8805  United States
# 8805  United States            2006    Movie   s8806  United States
# 8806          India            2015    Movie   s8807          India
#
#       release_year_y                                               cast  \
# 0               2020                                                NaN
# ...
